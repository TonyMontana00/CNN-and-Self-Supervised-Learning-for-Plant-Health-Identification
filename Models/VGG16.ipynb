# %% [markdown]
# # INITIAL SET UP

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Fix randomness and hide warnings

seed = 42

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd()+'/configs/'

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

import random
random.seed(seed)

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import matplotlib.pyplot as plt
plt.rc('font', size=16)
import seaborn as sns
from sklearn.model_selection import train_test_split, KFold
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# # DATA LOADING

# %%
# Load the dataset
dataset = np.load('/content/drive/MyDrive/[2023-2024] AN2DL/Challenge 1/public_data/public_data.npz', allow_pickle=True)

print(dataset.files)
# Out:
# ['data', 'labels']

# %%
# Extract the arrays from the data
data = dataset['data']
labels = dataset['labels']

# Convert data and labels values into the correct data_type
data = np.array(data, dtype=np.uint8)

print(data.shape)
print(labels.shape)
# Out:
# (5200, 96, 96, 3)
# (5200,)

# %% [markdown]
# # DATA SET PREPARATION

# %%
# Remove duplicates

def get_image_hash(image):
    # Convert image into a string
    image_string = image.tobytes()

    # Calculate the sum of byte values
    hash_value = sum(image_string)

    return hash_value

# Compute hash for each image
hashes = np.array([get_image_hash(image) for image in data])

# Find unique hashes and their indices
unique_hashes, indices = np.unique(hashes, return_index=True)

# Select the unique images and their corresponding labels
data_unique = data[indices]
labels_unique = labels[indices]

print(f"Original dataset size: {data.shape[0]}")
print(f"Unique dataset size: {data_unique.shape[0]}")
# Out:
# Original dataset size: 5200
# Unique dataset size: 4849

# %%
# Randomize the choice of images at each run
seed = random.randint(0, 1000)
random.seed(seed)
fig, ax = plt.subplots(1, 8, figsize=(20, 20))
for i in range(8):
    random_index = random.randint(0, data_unique.shape[0])
    ax[i].imshow(data_unique[random_index])
    ax[i].set_title(labels_unique[random_index])
    ax[i].axis('off')
plt.show()

# %%
# Show labels distribution

from collections import Counter

counter_labels = Counter(labels)
labels_count, counts = zip(*counter_labels.items())

plt.figure(figsize=(10, 5))
plt.bar(labels_count, counts)
plt.title('Distribution of labels')
plt.show()

# %%
#DOWNSAMPLING
# Find the indices of the healthy and unhealthy images

healthy_indices = np.where(labels_unique == 'healthy')[0]
unhealthy_indices = np.where(labels_unique == 'unhealthy')[0]

# Determine the number of images to sample from the healthy class to match the unhealthy class
num_samples = len(unhealthy_indices)

# Downsample the healthy class if necessary
if len(healthy_indices) > num_samples:
    healthy_downsampled_indices = np.random.choice(healthy_indices, size=num_samples, replace=False)
    new_indices = np.concatenate([healthy_downsampled_indices, unhealthy_indices])
else:
    new_indices = np.concatenate([healthy_indices, unhealthy_indices])

# Use the new indices to create your balanced dataset
data_balanced = data_unique[new_indices]
labels_balanced = labels_unique[new_indices]

# Function to count class instances
def count_classes(labels_to_count):
    unique, item_counts = np.unique(labels_to_count, return_counts=True)
    class_counts = dict(zip(unique, item_counts))
    return class_counts

# Count classes before downsampling
original_class_counts = count_classes(labels)
print("Original class counts:", original_class_counts)

# Count classes after downsampling
downsampled_class_counts = count_classes(labels_balanced)
print("Downsampled class counts:", downsampled_class_counts)

# Check if the classes are balanced after downsampling
if len(set(downsampled_class_counts.values())) == 1:
    print("The classes are balanced.")
else:
    print("The classes are not balanced.")

# %%
# UPSAMPLING
# Suppose data_unique and labels_unique are already defined

# Find the indices of the healthy and unhealthy images
healthy_indices = np.where(labels_unique == 'healthy')[0]
unhealthy_indices = np.where(labels_unique == 'unhealthy')[0]

# Determine the number of images to sample from the unhealthy class to match the healthy class
num_samples = len(healthy_indices)

# Upsample the unhealthy class
if len(unhealthy_indices) < num_samples:
    unhealthy_upsampled_indices = np.random.choice(unhealthy_indices, size=num_samples, replace=True)
    new_indices = np.concatenate([healthy_indices, unhealthy_upsampled_indices])
else:
    new_indices = np.concatenate([healthy_indices, unhealthy_indices])

# Use the new indices to create your balanced dataset
data_balanced = data_unique[new_indices]
labels_balanced = labels_unique[new_indices]

# Function to count class instances
def count_classes(labels_to_count):
    unique, item_counts = np.unique(labels_to_count, return_counts=True)
    class_counts = dict(zip(unique, item_counts))
    return class_counts

# Count classes before upsampling
original_class_counts = count_classes(labels_unique)
print("Original class counts:", original_class_counts)

# Count classes after upsampling
upsampled_class_counts = count_classes(labels_balanced)
print("Upsampled class counts:", upsampled_class_counts)

# Check if the classes are balanced after upsampling
if len(set(upsampled_class_counts.values())) == 1:
    print("The classes are balanced.")
else:
    print("The classes are not balanced.")

# Assume that 'data_unique' is a Numpy array of images and 'labels_unique' are the corresponding labels
# Use the indices of the upsampled 'unhealthy' class to get the images to be augmented
upsampled_unhealthy_images = data_unique[unhealthy_upsampled_indices]
# Out:
# Original class counts: {'healthy': 3060, 'unhealthy': 1789}
# Upsampled class counts: {'healthy': 3060, 'unhealthy': 3060}
# The classes are balanced.

# %%
# Convert labels to one-hot encoding
label_mapping = {'healthy': 0, 'unhealthy': 1}
numeric_labels = [label_mapping[label] for label in labels_balanced]
one_hot_labels = np.array(numeric_labels)

print(len(one_hot_labels))
print(len(data_balanced))
# Out:
# 6120
# 6120

# %% [markdown]
# #DATA SET SPLITTING

# %%
# Split the data into train_val and test sets with stratification to ensure that the distribution of labels is the same in both sets
train_val_data, test_data, train_val_labels, test_labels = train_test_split(data_balanced, one_hot_labels, test_size=0.15, random_state=seed, stratify=one_hot_labels)

# Further split the train_val set into train and val sets with stratification
train_data, val_data, train_labels, val_labels = train_test_split(train_val_data, train_val_labels, test_size=len(test_data), random_state=seed, stratify=train_val_labels)

# Print the shape of the train, val and test sets
print(train_data.shape, train_labels.shape)
print(val_data.shape, val_labels.shape)
print(test_data.shape, test_labels.shape)
# Out:
# (4284, 96, 96, 3) (4284,)
# (918, 96, 96, 3) (918,)
# (918, 96, 96, 3) (918,)

# %% [markdown]
# #VGG 16 MODEL

# %%
# Download and plot the VGG16 model
supernet = tfk.applications.VGG16(
    include_top=False,
    weights="imagenet",
    input_shape=(96,96,3)
)
supernet.summary()
tfk.utils.plot_model(supernet)


input_shape = (96, 96, 3)
epochs = 200
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 96, 96, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 96, 96, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 48, 48, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 48, 48, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 48, 48, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 24, 24, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 24, 24, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 24, 24, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 24, 24, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 12, 12, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 12, 12, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 6, 6, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 14714688 (56.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import tensorflow.keras.layers as tfkl

preprocessing = tf.keras.Sequential([
    tfkl.Rescaling(1./255),
    tfkl.RandomFlip("horizontal_and_vertical"),
    tfkl.RandomRotation(0.2),
    tfkl.RandomContrast(0.2),
    tfkl.RandomTranslation(0.2, 0.2),
], name='preprocessing')

# Use the supernet as feature extractor
supernet.trainable = False


inputs = tfk.Input(shape=(96,96,3))

preprocessing = preprocessing(inputs)

x = supernet(preprocessing)
x = tfkl.Flatten(name='Flattening')(x)
x = tfkl.Dropout(0.3, seed=seed)(x)
x = tfkl.Dense(
    256,
    activation='relu',
    kernel_initializer = tfk.initializers.GlorotUniform(seed))(x)
x = tfkl.Dropout(0.3, seed=seed)(x)
output_layer = tfkl.Dense(units=1, activation='sigmoid', kernel_initializer=tfk.initializers.GlorotUniform(seed), name='Output')(x)

# %%
# Connect input and output through the Model class
tl_model = tfk.Model(inputs=inputs, outputs=output_layer, name='model')

# %%
# Compile the model
tl_model.compile(loss=tfk.losses.BinaryCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])
tl_model.summary()


for i, layer in enumerate(tl_model.get_layer('vgg16').layers):
   layer.trainable = False

for i, layer in enumerate(tl_model.get_layer('vgg16').layers):
   print(i, layer.name, layer.trainable)


tl_callbacks = create_folders_and_callbacks(model_name = 'aug_transfer_learning_balanced_VGG')
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  preprocessing (Sequential)  (None, 96, 96, 3)         0
#
#  vgg16 (Functional)          (None, 3, 3, 512)         14714688
#
#  Flattening (Flatten)        (None, 4608)              0
#
#  dropout_8 (Dropout)         (None, 4608)              0
#
#  dense_4 (Dense)             (None, 256)               1179904
#
#  dropout_9 (Dropout)         (None, 256)               0
#
#  Output (Dense)              (None, 1)                 257
#
# =================================================================
# Total params: 15894849 (60.63 MB)
# Trainable params: 1180161 (4.50 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________
# 0 input_1 False
# 1 block1_conv1 False
# 2 block1_conv2 False
# 3 block1_pool False
# 4 block2_conv1 False
# 5 block2_conv2 False
# 6 block2_pool False
# 7 block3_conv1 False
# 8 block3_conv2 False
# 9 block3_conv3 False
# 10 block3_pool False
# 11 block4_conv1 False
# 12 block4_conv2 False
# 13 block4_conv3 False
# 14 block4_pool False
# 15 block5_conv1 False
# 16 block5_conv2 False
# 17 block5_conv3 False
# 18 block5_pool False

# %%
# Train the model
tl_history = tl_model.fit(
    x = train_data,
    y= train_labels,
    epochs = epochs,
    validation_data = (val_data, val_labels),
    callbacks = [tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=10, restore_best_weights=True)]
).history
# Out:
# Epoch 1/200
# 134/134 [==============================] - 9s 48ms/step - loss: 0.6606 - accuracy: 0.6342 - precision_4: 0.6357 - recall_4: 0.6289 - val_loss: 0.5891 - val_accuracy: 0.6732 - val_precision_4: 0.7033 - val_recall_4: 0.5991
# Epoch 2/200
# 134/134 [==============================] - 5s 36ms/step - loss: 0.6060 - accuracy: 0.6774 - precision_4: 0.6870 - recall_4: 0.6517 - val_loss: 0.5695 - val_accuracy: 0.6765 - val_precision_4: 0.6761 - val_recall_4: 0.6776
# Epoch 3/200
# 134/134 [==============================] - 6s 42ms/step - loss: 0.5866 - accuracy: 0.6786 - precision_4: 0.6893 - recall_4: 0.6503 - val_loss: 0.5612 - val_accuracy: 0.6906 - val_precision_4: 0.6797 - val_recall_4: 0.7211
# Epoch 4/200
# 134/134 [==============================] - 5s 40ms/step - loss: 0.5816 - accuracy: 0.6919 - precision_4: 0.7110 - recall_4: 0.6466 - val_loss: 0.5503 - val_accuracy: 0.6874 - val_precision_4: 0.6799 - val_recall_4: 0.7081
# Epoch 5/200
# 134/134 [==============================] - 6s 41ms/step - loss: 0.5725 - accuracy: 0.6998 - precision_4: 0.7136 - recall_4: 0.6676 - val_loss: 0.5439 - val_accuracy: 0.7004 - val_precision_4: 0.7160 - val_recall_4: 0.6645
# Epoch 6/200
# 134/134 [==============================] - 5s 41ms/step - loss: 0.5793 - accuracy: 0.6926 - precision_4: 0.7136 - recall_4: 0.6433 - val_loss: 0.5393 - val_accuracy: 0.7288 - val_precision_4: 0.7225 - val_recall_4: 0.7429
# Epoch 7/200
# 134/134 [==============================] - 5s 36ms/step - loss: 0.5743 - accuracy: 0.6954 - precision_4: 0.7077 - recall_4: 0.6657 - val_loss: 0.5444 - val_accuracy: 0.7026 - val_precision_4: 0.7943 - val_recall_4: 0.5468
# Epoch 8/200
# 134/134 [==============================] - 6s 42ms/step - loss: 0.5643 - accuracy: 0.7063 - precision_4: 0.7226 - recall_4: 0.6699 - val_loss: 0.5602 - val_accuracy: 0.7004 - val_precision_4: 0.7754 - val_recall_4: 0.5643
# Epoch 9/200
# 134/134 [==============================] - 5s 40ms/step - loss: 0.5594 - accuracy: 0.7082 - precision_4: 0.7212 - recall_4: 0.6788 - val_loss: 0.5282 - val_accuracy: 0.7081 - val_precision_4: 0.7175 - val_recall_4: 0.6863
# Epoch 10/200
# 134/134 [==============================] - 5s 40ms/step - loss: 0.5613 - accuracy: 0.7070 - precision_4: 0.7228 - recall_4: 0.6718 - val_loss: 0.5318 - val_accuracy: 0.7004 - val_precision_4: 0.7383 - val_recall_4: 0.6209
# Epoch 11/200
# 134/134 [==============================] - 5s 40ms/step - loss: 0.5567 - accuracy: 0.7122 - precision_4: 0.7269 - recall_4: 0.6797 - val_loss: 0.5177 - val_accuracy: 0.7266 - val_precision_4: 0.7500 - val_recall_4: 0.6797
# Epoch 12/200
# 134/134 [==============================] - 5s 40ms/step - loss: 0.5531 - accuracy: 0.7063 - precision_4: 0.7146 - recall_4: 0.6872 - val_loss: 0.5161 - val_accuracy: 0.7418 - val_precision_4: 0.7445 - val_recall_4: 0.7364
# Epoch 13/200
# 134/134 [==============================] - 5s 38ms/step - loss: 0.5479 - accuracy: 0.7171 - precision_4: 0.7327 - recall_4: 0.6835 - val_loss: 0.5054 - val_accuracy: 0.7364 - val_precision_4: 0.7706 - val_recall_4: 0.6732
# Epoch 14/200
# 134/134 [==============================] - 5s 36ms/step - loss: 0.5459 - accuracy: 0.7180 - precision_4: 0.7283 - recall_4: 0.6956 - val_loss: 0.5201 - val_accuracy: 0.7309 - val_precision_4: 0.7236 - val_recall_4: 0.7473
# Epoch 15/200
# 134/134 [==============================] - 5s 40ms/step - loss: 0.5357 - accuracy: 0.7269 - precision_4: 0.7359 - recall_4: 0.7077 - val_loss: 0.5211 - val_accuracy: 0.7222 - val_precision_4: 0.7287 - val_recall_4: 0.7081
# Epoch 16/200
# 134/134 [==============================] - 6s 41ms/step - loss: 0.5392 - accuracy: 0.7264 - precision_4: 0.7354 - recall_4: 0.7073 - val_loss: 0.5256 - val_accuracy: 0.7255 - val_precision_4: 0.8265 - val_recall_4: 0.5708
# Epoch 17/200
# 134/134 [==============================] - 5s 40ms/step - loss: 0.5450 - accuracy: 0.7187 - precision_4: 0.7327 - recall_4: 0.6886 - val_loss: 0.5104 - val_accuracy: 0.7484 - val_precision_4: 0.8132 - val_recall_4: 0.6449
# Epoch 18/200
# 134/134 [==============================] - 5s 38ms/step - loss: 0.5398 - accuracy: 0.7162 - precision_4: 0.7245 - recall_4: 0.6975 - val_loss: 0.5090 - val_accuracy: 0.7364 - val_precision_4: 0.7256 - val_recall_4: 0.7603
# Epoch 19/200
# 134/134 [==============================] - 5s 40ms/step - loss: 0.5334 - accuracy: 0.7285 - precision_4: 0.7413 - recall_4: 0.7021 - val_loss: 0.5147 - val_accuracy: 0.7277 - val_precision_4: 0.7238 - val_recall_4: 0.7364
# Epoch 20/200
# 134/134 [==============================] - 5s 37ms/step - loss: 0.5419 - accuracy: 0.7204 - precision_4: 0.7269 - recall_4: 0.7059 - val_loss: 0.5294 - val_accuracy: 0.7211 - val_precision_4: 0.7875 - val_recall_4: 0.6057
# Epoch 21/200
# 134/134 [==============================] - 6s 42ms/step - loss: 0.5178 - accuracy: 0.7369 - precision_4: 0.7474 - recall_4: 0.7157 - val_loss: 0.5181 - val_accuracy: 0.7375 - val_precision_4: 0.7064 - val_recall_4: 0.8126
# Epoch 22/200
# 134/134 [==============================] - 5s 40ms/step - loss: 0.5352 - accuracy: 0.7288 - precision_4: 0.7331 - recall_4: 0.7194 - val_loss: 0.5323 - val_accuracy: 0.7244 - val_precision_4: 0.7861 - val_recall_4: 0.6166
# Epoch 23/200
# 134/134 [==============================] - 6s 42ms/step - loss: 0.5249 - accuracy: 0.7330 - precision_4: 0.7418 - recall_4: 0.7148 - val_loss: 0.4977 - val_accuracy: 0.7538 - val_precision_4: 0.7654 - val_recall_4: 0.7320
# Epoch 24/200
# 134/134 [==============================] - 5s 40ms/step - loss: 0.5268 - accuracy: 0.7320 - precision_4: 0.7446 - recall_4: 0.7063 - val_loss: 0.4949 - val_accuracy: 0.7549 - val_precision_4: 0.7970 - val_recall_4: 0.6841
# Epoch 25/200
# 134/134 [==============================] - 5s 40ms/step - loss: 0.5290 - accuracy: 0.7355 - precision_4: 0.7496 - recall_4: 0.7073 - val_loss: 0.5324 - val_accuracy: 0.7298 - val_precision_4: 0.8168 - val_recall_4: 0.5926
# Epoch 26/200
# 134/134 [==============================] - 5s 41ms/step - loss: 0.5208 - accuracy: 0.7334 - precision_4: 0.7439 - recall_4: 0.7120 - val_loss: 0.5126 - val_accuracy: 0.7309 - val_precision_4: 0.7512 - val_recall_4: 0.6906
# Epoch 27/200
# 134/134 [==============================] - 5s 36ms/step - loss: 0.5169 - accuracy: 0.7346 - precision_4: 0.7426 - recall_4: 0.7180 - val_loss: 0.5088 - val_accuracy: 0.7538 - val_precision_4: 0.7495 - val_recall_4: 0.7625
# Epoch 28/200
# 134/134 [==============================] - 5s 38ms/step - loss: 0.5170 - accuracy: 0.7365 - precision_4: 0.7427 - recall_4: 0.7236 - val_loss: 0.5024 - val_accuracy: 0.7462 - val_precision_4: 0.7883 - val_recall_4: 0.6732
# Epoch 29/200
# 134/134 [==============================] - 5s 40ms/step - loss: 0.5192 - accuracy: 0.7381 - precision_4: 0.7485 - recall_4: 0.7171 - val_loss: 0.5212 - val_accuracy: 0.7538 - val_precision_4: 0.8209 - val_recall_4: 0.6492
# Epoch 30/200
# 134/134 [==============================] - 5s 37ms/step - loss: 0.5158 - accuracy: 0.7365 - precision_4: 0.7465 - recall_4: 0.7162 - val_loss: 0.4877 - val_accuracy: 0.7647 - val_precision_4: 0.8140 - val_recall_4: 0.6863
# Epoch 31/200
# 134/134 [==============================] - 5s 38ms/step - loss: 0.5214 - accuracy: 0.7264 - precision_4: 0.7286 - recall_4: 0.7218 - val_loss: 0.5091 - val_accuracy: 0.7342 - val_precision_4: 0.7438 - val_recall_4: 0.7146
# Epoch 32/200
# 134/134 [==============================] - 5s 36ms/step - loss: 0.5193 - accuracy: 0.7372 - precision_4: 0.7485 - recall_4: 0.7143 - val_loss: 0.5010 - val_accuracy: 0.7473 - val_precision_4: 0.7888 - val_recall_4: 0.6754
# Epoch 33/200
# 134/134 [==============================] - 5s 40ms/step - loss: 0.5131 - accuracy: 0.7437 - precision_4: 0.7587 - recall_4: 0.7148 - val_loss: 0.4994 - val_accuracy: 0.7440 - val_precision_4: 0.7324 - val_recall_4: 0.7691
# Epoch 34/200
# 134/134 [==============================] - 5s 37ms/step - loss: 0.5183 - accuracy: 0.7353 - precision_4: 0.7333 - recall_4: 0.7395 - val_loss: 0.5038 - val_accuracy: 0.7462 - val_precision_4: 0.7811 - val_recall_4: 0.6841
# Epoch 35/200
# 134/134 [==============================] - 5s 36ms/step - loss: 0.5230 - accuracy: 0.7264 - precision_4: 0.7299 - recall_4: 0.7190 - val_loss: 0.5039 - val_accuracy: 0.7527 - val_precision_4: 0.7522 - val_recall_4: 0.7538
# Epoch 36/200
# 134/134 [==============================] - 5s 38ms/step - loss: 0.5085 - accuracy: 0.7495 - precision_4: 0.7460 - recall_4: 0.7568 - val_loss: 0.5195 - val_accuracy: 0.7277 - val_precision_4: 0.8255 - val_recall_4: 0.5773
# Epoch 37/200
# 134/134 [==============================] - 5s 37ms/step - loss: 0.5089 - accuracy: 0.7549 - precision_4: 0.7602 - recall_4: 0.7446 - val_loss: 0.5022 - val_accuracy: 0.7582 - val_precision_4: 0.8078 - val_recall_4: 0.6776
# Epoch 38/200
# 133/134 [============================>.] - ETA: 0s - loss: 0.5009 - accuracy: 0.7498 - precision_4: 0.7508 - recall_4: 0.7505
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-25020667b146> in <cell line: 2>()
#       1 # Train the model
# ----> 2 tl_history = tl_model.fit(
#       3     x = train_data,
#       4     y= train_labels,
#       5     epochs = epochs,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1830                             pss_evaluation_shards=self._pss_evaluation_shards,
#    1831                         )
# -> 1832                     val_logs = self.evaluate(
#    1833                         x=val_x,
#    1834                         y=val_y,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# KeyboardInterrupt:

# %%
# Plot the training
plt.figure(figsize=(15,5))

plt.plot(tl_history['loss'],label = 'Training Loss', alpha=.3, color='#4D61E2', linestyle='--')
plt.plot(tl_history['val_loss'], label='Validation Loss', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Binary Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))

plt.plot(tl_history['accuracy'],label = 'Training Accuracy' , alpha=.3, color='#4D61E2', linestyle='--')
plt.plot(tl_history['val_accuracy'], label='Validation accuracy', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the best model
tl_model.save('VGG16_model')

# %%
# Re-load the model after transfer learning
tl_model = tfk.models.load_model('VGG16_model')
tl_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  preprocessing (Sequential)  (None, 96, 96, 3)         0
#
#  vgg16 (Functional)          (None, 3, 3, 512)         14714688
#
#  Flattening (Flatten)        (None, 4608)              0
#
#  dropout_2 (Dropout)         (None, 4608)              0
#
#  dense_1 (Dense)             (None, 1024)              4719616
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  Output (Dense)              (None, 1)                 1025
#
# =================================================================
# Total params: 19435329 (74.14 MB)
# Trainable params: 4720641 (18.01 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
# Set all VGG layers to True
tl_model.get_layer('vgg16').trainable = True
for i, layer in enumerate(tl_model.get_layer('vgg16').layers):
   print(i, layer.name, layer.trainable)
# Out:
# 0 input_1 True
# 1 block1_conv1 True
# 2 block1_conv2 True
# 3 block1_pool True
# 4 block2_conv1 True
# 5 block2_conv2 True
# 6 block2_pool True
# 7 block3_conv1 True
# 8 block3_conv2 True
# 9 block3_conv3 True
# 10 block3_pool True
# 11 block4_conv1 True
# 12 block4_conv2 True
# 13 block4_conv3 True
# 14 block4_pool True
# 15 block5_conv1 True
# 16 block5_conv2 True
# 17 block5_conv3 True
# 18 block5_pool True

# %%
# Freeze first N layers, e.g., until 14th
for i, layer in enumerate(tl_model.get_layer('vgg16').layers[:15]):
  layer.trainable=False
for i, layer in enumerate(tl_model.get_layer('vgg16').layers):
   print(i, layer.name, layer.trainable)
tl_model.summary()
# Out:
# 0 input_1 False
# 1 block1_conv1 False
# 2 block1_conv2 False
# 3 block1_pool False
# 4 block2_conv1 False
# 5 block2_conv2 False
# 6 block2_pool False
# 7 block3_conv1 False
# 8 block3_conv2 False
# 9 block3_conv3 False
# 10 block3_pool False
# 11 block4_conv1 False
# 12 block4_conv2 False
# 13 block4_conv3 False
# 14 block4_pool False
# 15 block5_conv1 True
# 16 block5_conv2 True
# 17 block5_conv3 True
# 18 block5_pool True
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  preprocessing (Sequential)  (None, 96, 96, 3)         0
#
#  vgg16 (Functional)          (None, 3, 3, 512)         14714688
#
#  Flattening (Flatten)        (None, 4608)              0
#
#  dropout_2 (Dropout)         (None, 4608)              0
#
#  dense_1 (Dense)             (None, 1024)              4719616
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  Output (Dense)              (None, 1)                 1025
#
# =================================================================
# Total params: 19435329 (74.14 MB)
# Trainable params: 11800065 (45.01 MB)
# Non-trainable params: 7635264 (29.13 MB)
# _________________________________________________________________

# %%
# Compile the model
tl_model.compile(loss=tfk.losses.BinaryCrossentropy(), optimizer=tfk.optimizers.Adam(1e-4), metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

# %%
# Fine-tune the model
tl_history = tl_model.fit(
    x = train_data,
    y= train_labels,
    epochs = epochs,
    validation_data = (val_data, val_labels),
    callbacks = [tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=10, verbose=2 , restore_best_weights=True)]
).history
# Out:
# Epoch 1/200
# 134/134 [==============================] - 11s 51ms/step - loss: 0.6418 - accuracy: 0.6431 - precision_1: 0.6446 - recall_1: 0.6377 - val_loss: 0.6117 - val_accuracy: 0.6275 - val_precision_1: 0.5857 - val_recall_1: 0.8715
# Epoch 2/200
# 134/134 [==============================] - 6s 49ms/step - loss: 0.5613 - accuracy: 0.6975 - precision_1: 0.7065 - recall_1: 0.6755 - val_loss: 0.5123 - val_accuracy: 0.7266 - val_precision_1: 0.7600 - val_recall_1: 0.6623
# Epoch 3/200
# 134/134 [==============================] - 6s 47ms/step - loss: 0.5284 - accuracy: 0.7353 - precision_1: 0.7447 - recall_1: 0.7162 - val_loss: 0.5137 - val_accuracy: 0.7342 - val_precision_1: 0.7541 - val_recall_1: 0.6950
# Epoch 4/200
# 134/134 [==============================] - 7s 52ms/step - loss: 0.5135 - accuracy: 0.7381 - precision_1: 0.7429 - recall_1: 0.7283 - val_loss: 0.4703 - val_accuracy: 0.7614 - val_precision_1: 0.7105 - val_recall_1: 0.8824
# Epoch 5/200
# 134/134 [==============================] - 6s 47ms/step - loss: 0.5032 - accuracy: 0.7481 - precision_1: 0.7525 - recall_1: 0.7395 - val_loss: 0.4963 - val_accuracy: 0.7462 - val_precision_1: 0.6823 - val_recall_1: 0.9216
# Epoch 6/200
# 134/134 [==============================] - 7s 51ms/step - loss: 0.4692 - accuracy: 0.7787 - precision_1: 0.7881 - recall_1: 0.7624 - val_loss: 0.4704 - val_accuracy: 0.7484 - val_precision_1: 0.7209 - val_recall_1: 0.8105
# Epoch 7/200
# 134/134 [==============================] - 7s 50ms/step - loss: 0.4613 - accuracy: 0.7782 - precision_1: 0.7956 - recall_1: 0.7488 - val_loss: 0.4867 - val_accuracy: 0.7603 - val_precision_1: 0.7812 - val_recall_1: 0.7233
# Epoch 8/200
# 134/134 [==============================] - 7s 51ms/step - loss: 0.4438 - accuracy: 0.7859 - precision_1: 0.7938 - recall_1: 0.7726 - val_loss: 0.4023 - val_accuracy: 0.8017 - val_precision_1: 0.8420 - val_recall_1: 0.7429
# Epoch 9/200
# 134/134 [==============================] - 6s 46ms/step - loss: 0.4621 - accuracy: 0.7794 - precision_1: 0.7865 - recall_1: 0.7670 - val_loss: 0.4946 - val_accuracy: 0.7745 - val_precision_1: 0.7716 - val_recall_1: 0.7800
# Epoch 10/200
# 134/134 [==============================] - 7s 51ms/step - loss: 0.4456 - accuracy: 0.7873 - precision_1: 0.7941 - recall_1: 0.7759 - val_loss: 0.4389 - val_accuracy: 0.7778 - val_precision_1: 0.7365 - val_recall_1: 0.8649
# Epoch 11/200
# 134/134 [==============================] - 6s 46ms/step - loss: 0.4182 - accuracy: 0.8072 - precision_1: 0.8157 - recall_1: 0.7937 - val_loss: 0.4555 - val_accuracy: 0.7614 - val_precision_1: 0.7198 - val_recall_1: 0.8562
# Epoch 12/200
# 134/134 [==============================] - 7s 51ms/step - loss: 0.4209 - accuracy: 0.8011 - precision_1: 0.8137 - recall_1: 0.7810 - val_loss: 0.3891 - val_accuracy: 0.8072 - val_precision_1: 0.8691 - val_recall_1: 0.7233
# Epoch 13/200
# 134/134 [==============================] - 7s 50ms/step - loss: 0.4069 - accuracy: 0.8028 - precision_1: 0.8093 - recall_1: 0.7923 - val_loss: 0.4010 - val_accuracy: 0.7974 - val_precision_1: 0.7661 - val_recall_1: 0.8562
# Epoch 14/200
# 134/134 [==============================] - 7s 51ms/step - loss: 0.3998 - accuracy: 0.8053 - precision_1: 0.8129 - recall_1: 0.7932 - val_loss: 0.4353 - val_accuracy: 0.7887 - val_precision_1: 0.8288 - val_recall_1: 0.7277
# Epoch 15/200
# 134/134 [==============================] - 7s 50ms/step - loss: 0.3860 - accuracy: 0.8268 - precision_1: 0.8340 - recall_1: 0.8161 - val_loss: 0.4510 - val_accuracy: 0.8072 - val_precision_1: 0.8490 - val_recall_1: 0.7473
# Epoch 16/200
# 134/134 [==============================] - 7s 51ms/step - loss: 0.3774 - accuracy: 0.8259 - precision_1: 0.8346 - recall_1: 0.8128 - val_loss: 0.4538 - val_accuracy: 0.7778 - val_precision_1: 0.7392 - val_recall_1: 0.8584
# Epoch 17/200
# 134/134 [==============================] - 6s 47ms/step - loss: 0.3816 - accuracy: 0.8226 - precision_1: 0.8244 - recall_1: 0.8198 - val_loss: 0.4126 - val_accuracy: 0.8050 - val_precision_1: 0.9070 - val_recall_1: 0.6797
# Epoch 18/200
# 134/134 [==============================] - 7s 51ms/step - loss: 0.3686 - accuracy: 0.8312 - precision_1: 0.8314 - recall_1: 0.8310 - val_loss: 0.4055 - val_accuracy: 0.8061 - val_precision_1: 0.7921 - val_recall_1: 0.8301
# Epoch 19/200
# 134/134 [==============================] - 7s 50ms/step - loss: 0.3684 - accuracy: 0.8399 - precision_1: 0.8405 - recall_1: 0.8389 - val_loss: 0.3642 - val_accuracy: 0.8355 - val_precision_1: 0.8889 - val_recall_1: 0.7669
# Epoch 20/200
# 134/134 [==============================] - 7s 51ms/step - loss: 0.3585 - accuracy: 0.8329 - precision_1: 0.8408 - recall_1: 0.8212 - val_loss: 0.3688 - val_accuracy: 0.8181 - val_precision_1: 0.8288 - val_recall_1: 0.8017
# Epoch 21/200
# 134/134 [==============================] - 7s 50ms/step - loss: 0.3534 - accuracy: 0.8459 - precision_1: 0.8529 - recall_1: 0.8361 - val_loss: 0.3880 - val_accuracy: 0.8246 - val_precision_1: 0.8143 - val_recall_1: 0.8410
# Epoch 22/200
# 134/134 [==============================] - 7s 51ms/step - loss: 0.3457 - accuracy: 0.8436 - precision_1: 0.8462 - recall_1: 0.8399 - val_loss: 0.4310 - val_accuracy: 0.8235 - val_precision_1: 0.9280 - val_recall_1: 0.7015
# Epoch 23/200
# 134/134 [==============================] - 6s 46ms/step - loss: 0.3410 - accuracy: 0.8529 - precision_1: 0.8603 - recall_1: 0.8427 - val_loss: 0.3825 - val_accuracy: 0.8301 - val_precision_1: 0.8875 - val_recall_1: 0.7560
# Epoch 24/200
# 134/134 [==============================] - 6s 47ms/step - loss: 0.3223 - accuracy: 0.8604 - precision_1: 0.8652 - recall_1: 0.8539 - val_loss: 0.4189 - val_accuracy: 0.8203 - val_precision_1: 0.8808 - val_recall_1: 0.7407
# Epoch 25/200
# 134/134 [==============================] - 7s 50ms/step - loss: 0.3257 - accuracy: 0.8534 - precision_1: 0.8537 - recall_1: 0.8529 - val_loss: 0.4110 - val_accuracy: 0.8290 - val_precision_1: 0.9037 - val_recall_1: 0.7364
# Epoch 26/200
# 134/134 [==============================] - 7s 51ms/step - loss: 0.3293 - accuracy: 0.8543 - precision_1: 0.8553 - recall_1: 0.8529 - val_loss: 0.3878 - val_accuracy: 0.8279 - val_precision_1: 0.8460 - val_recall_1: 0.8017
# Epoch 27/200
# 134/134 [==============================] - 6s 46ms/step - loss: 0.3219 - accuracy: 0.8543 - precision_1: 0.8527 - recall_1: 0.8567 - val_loss: 0.3979 - val_accuracy: 0.8159 - val_precision_1: 0.7799 - val_recall_1: 0.8802
# Epoch 28/200
# 134/134 [==============================] - 6s 47ms/step - loss: 0.3248 - accuracy: 0.8557 - precision_1: 0.8554 - recall_1: 0.8562 - val_loss: 0.3638 - val_accuracy: 0.8170 - val_precision_1: 0.8129 - val_recall_1: 0.8235
# Epoch 29/200
# 133/134 [============================>.] - ETA: 0s - loss: 0.3129 - accuracy: 0.8656 - precision_1: 0.8626 - recall_1: 0.8699Restoring model weights from the end of the best epoch: 19.
# 134/134 [==============================] - 7s 51ms/step - loss: 0.3135 - accuracy: 0.8653 - precision_1: 0.8631 - recall_1: 0.8683 - val_loss: 0.4086 - val_accuracy: 0.8322 - val_precision_1: 0.9003 - val_recall_1: 0.7473
# Epoch 29: early stopping

# %%
# Plot the training
plt.figure(figsize=(15,5))

plt.plot(tl_history['loss'],label = 'Training Loss', alpha=.3, color='#4D61E2', linestyle='--')
plt.plot(tl_history['val_loss'], label='Validation Loss', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Binary Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))

plt.plot(tl_history['accuracy'],label = 'Training Accuracy' , alpha=.3, color='#4D61E2', linestyle='--')
plt.plot(tl_history['val_accuracy'], label='Validation accuracy', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the best model
tl_model.save('VGG16_model_fine_tuned')

# %%
# Re-load the model after fine tuning
tl_model = tfk.models.load_model('VGG16_model_fine_tuned')
tl_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  preprocessing (Sequential)  (None, 96, 96, 3)         0
#
#  vgg16 (Functional)          (None, 3, 3, 512)         14714688
#
#  Flattening (Flatten)        (None, 4608)              0
#
#  dropout_2 (Dropout)         (None, 4608)              0
#
#  dense_1 (Dense)             (None, 1024)              4719616
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  Output (Dense)              (None, 1)                 1025
#
# =================================================================
# Total params: 19435329 (74.14 MB)
# Trainable params: 11800065 (45.01 MB)
# Non-trainable params: 7635264 (29.13 MB)
# _________________________________________________________________

# %%
# Assign the evaluation results to metrics varables
loss, accuracy, precision, recall = tl_model.evaluate(test_data, test_labels)

# Print the metrics
print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
# Out:
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3707 - accuracy: 0.8257 - precision_1: 0.8903 - recall_1: 0.7429
# Loss: 0.3707190155982971
# Accuracy: 0.8257080316543579
# Precision: 0.8903394341468811
# Recall: 0.742919385433197

# %%
# Obtain the predicted values by the model
predictions = tl_model.predict(test_data)

# Display the shape of the predictions
print("Predictions Shape:", predictions.shape)

# Obtain labels as 0 or 1 for binary classification
predicted_classes = np.where(predictions > 0.5, 1, 0)
# Out:
# 29/29 [==============================] - 1s 28ms/step
# Predictions Shape: (918, 1)

# %%
# Calculate the confusion matrix
conf_matrix = confusion_matrix(test_labels, predicted_classes)

# Print the confusion matrix
print(conf_matrix)

# Plot the confusion matrix
sns.heatmap(conf_matrix, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# [[417  42]
#  [118 341]]

# %%
# Calculate and print the classification report
report = classification_report(test_labels, predicted_classes)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.91      0.84       459
#            1       0.89      0.74      0.81       459
#
#     accuracy                           0.83       918
#    macro avg       0.83      0.83      0.82       918
# weighted avg       0.83      0.83      0.82       918
