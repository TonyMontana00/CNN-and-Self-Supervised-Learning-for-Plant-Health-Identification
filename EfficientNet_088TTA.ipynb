# %% [markdown]
# #INITIAL SETUP

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
  # Fix randomness and hide warnings
  seed = 42

  import os
  os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
  os.environ['PYTHONHASHSEED'] = str(seed)
  os.environ['MPLCONFIGDIR'] = os.getcwd()+'/configs/'

  import warnings
  warnings.simplefilter(action='ignore', category=FutureWarning)
  warnings.simplefilter(action='ignore', category=Warning)

  import numpy as np
  np.random.seed(seed)

  import logging

  import random
  random.seed(seed)

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import matplotlib.pyplot as plt
plt.rc('font', size=16)
import seaborn as sns
from sklearn.model_selection import train_test_split, KFold
import cv2
from keras.applications.efficientnet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# %%
#GLOBAL VARIABLES
UPSAMPLING = False
BEST_TTA_ACCURACY=0

# %%
# %cd /content/drive/MyDrive/Challenge1/Challenge1_Luca
# Out:
# /content/drive/.shortcut-targets-by-id/1NoJFi6sZk7HK6-01JmQLA6FmpPbKh2jd/Challenge1/Challenge1_Luca

# %% [markdown]
# #DATA LOADING

# %%
# Load the dataset
dataset = np.load('../extracted_data/public_data.npz', allow_pickle=True)

# Extract the arrays from the data
data = dataset['data']
labels = dataset['labels']

# Convert data and labels values into the correct data_type
data = np.array(data, dtype=np.uint8)

print(data.shape)
print(labels.shape)
# Out:
# (5200, 96, 96, 3)
# (5200,)

# %% [markdown]
# # DATA SET PREPARATION

# %%
def get_image_hash(image):
    #Converti l'immagine in una stringa
    image_string = image.tobytes()

    #Calcola la somma dei valori dei byte
    hash_value = sum(image_string)

    return hash_value

#Compute hash for each image
hashes = np.array([get_image_hash(image) for image in data])

#Find unique hashes and their indices
unique_hashes, indices = np.unique(hashes, return_index=True)

#Select the unique images and their corresponding labels
data_unique = data[indices]
labels_unique = labels[indices]

print(f"Original dataset size: {data.shape[0]}")
print(f"Unique dataset size: {data_unique.shape[0]}")
# Out:
# Original dataset size: 5200
# Unique dataset size: 4849

# %%
# randomize the choice of images at each run
seed = random.randint(0, 1000)
random.seed(seed)
fig, ax = plt.subplots(1, 8, figsize=(20, 20))
for i in range(8):
    random_index = random.randint(0, data_unique.shape[0])
    ax[i].imshow(data_unique[random_index])
    ax[i].set_title(labels_unique[random_index])
    ax[i].axis('off')
plt.show()

# %%
from collections import Counter

counter_labels = Counter(labels)
labels_count, counts = zip(*counter_labels.items())

plt.figure(figsize=(10, 5))
plt.bar(labels_count, counts)
plt.title('Distribution of labels')
plt.show()

# %%
#UPSAMPLING
#Find the indices of the healthy and unhealthy images
UPSAMPLING = True
healthy_indices = np.where(labels_unique == 'healthy')[0]
unhealthy_indices = np.where(labels_unique == 'unhealthy')[0]

#Determine the number of images to sample from the unhealthy class to match the healthy class
num_samples = len(healthy_indices)

#Upsample the unhealthy class
if len(unhealthy_indices) < num_samples:
    unhealthy_upsampled_indices = np.random.choice(unhealthy_indices, size=num_samples, replace=True)
    new_indices = np.concatenate([healthy_indices, unhealthy_upsampled_indices])
else:
    new_indices = np.concatenate([healthy_indices, unhealthy_indices])

#Use the new indices to create a balanced dataset
data_balanced = data_unique[new_indices]
labels_balanced = labels_unique[new_indices]

#Function to count class instances
def count_classes(labels_to_count):
    unique, item_counts = np.unique(labels_to_count, return_counts=True)
    class_counts = dict(zip(unique, item_counts))
    return class_counts

# Count classes before upsampling
original_class_counts = count_classes(labels_unique)
print("Original class counts:", original_class_counts)

# Count classes after upsampling
upsampled_class_counts = count_classes(labels_balanced)
print("Upsampled class counts:", upsampled_class_counts)

# Check if the classes are balanced after upsampling
if len(set(upsampled_class_counts.values())) == 1:
    print("The classes are balanced.")
else:
    print("The classes are not balanced.")

# Use the indices of the upsampled 'unhealthy' class to get the images to be augmented
upsampled_unhealthy_images = data_unique[unhealthy_upsampled_indices]
# Out:
# Original class counts: {'healthy': 3060, 'unhealthy': 1789}
# Upsampled class counts: {'healthy': 3060, 'unhealthy': 3060}
# The classes are balanced.

# %%
# Convert labels to one-hot encoding
label_mapping = {'healthy': 0, 'unhealthy': 1}
if not UPSAMPLING:
  numeric_labels = [label_mapping[label] for label in labels_unique]
else:
  numeric_labels = [label_mapping[label] for label in labels_balanced]

one_hot_labels = np.array(numeric_labels)

# %% [markdown]
# #DATA SET SPLITTING

# %%
# Split the data into training and validation sets
# 85% of the data goes into the training set and 15% into the validation set
if UPSAMPLING:
  train_data, val_data, train_labels, val_labels = train_test_split(
      data_balanced, one_hot_labels, test_size=0.15, random_state=seed, stratify=one_hot_labels)
else:
  train_data, val_data, train_labels, val_labels = train_test_split(
      data_unique, one_hot_labels, test_size=0.15, random_state=seed, stratify=one_hot_labels)

# Print the shape of the training and validation sets
print(train_data.shape, train_labels.shape)
print(val_data.shape, val_labels.shape)
# Out:
# (4121, 96, 96, 3) (4121,)
# (728, 96, 96, 3) (728,)

# %% [markdown]
# #EFFICIENT_NETB0 MODEL

# %% [markdown]
# ##TRANSFER LEARNING

# %% [markdown]
# ###model definition

# %%
from tensorflow.keras.applications import EfficientNetB0

#efficientNetB0 imported from keras as base model
base_model = EfficientNetB0(
    include_top=False,
    weights='imagenet',
    input_tensor=None,
    input_shape=(224,224,3),
    pooling=None
)

#set the efficientNet to non trainable for transfer learning
base_model.trainable = False

#pre processing layers
preprocessing = tf.keras.Sequential([
    tf.keras.layers.Lambda(preprocess_input, input_shape=(96, 96, 3)),
    tf.keras.layers.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.RandomRotation(0.2),
    tf.keras.layers.RandomContrast(0.2),
    tf.keras.layers.RandomTranslation(0.2, 0.2),
], name='preprocessing')

inputs = tfk.Input(shape=(96,96,3))

preprocessing = preprocessing(inputs)
x = tf.keras.layers.Resizing( 224, 224, interpolation='bilinear', crop_to_aspect_ratio=True,) (preprocessing)
x = base_model(x, training=False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tfkl.Dropout(0.5, seed=seed)(x)
x = tfkl.Dense(
    1024,
    activation='leaky_relu',)(x)

output_layer = tfkl.Dense(units=1, activation='sigmoid', name='Output')(x)

# Connect input and output through the Model class
model = tfk.Model(inputs=inputs, outputs=output_layer, name='model')


learning_rate = 5e-4

# compile the model
model.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
    metrics=['accuracy']
)

# %% [markdown]
# definitons of the callbacks to pass to the model

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=12, restore_best_weights=True)

rlrop = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience= 6, factor= 0.5, min_lr= 5e-5, verbose=1)

callbacks = []

callbacks.append(rlrop)
callbacks.append(early_stopping)

# %% [markdown]
# ###k fold cross validation

# %% [markdown]
# we use k fold cross validation to see if the values of accuracy and loss are consistent over each fold. We also keep track of the best epoch in order to use it later to train the model on the entire data-set.

# %%
# Define the number of splits for KFold
n_splits = 4
foldCount= 1
kf = KFold(n_splits=n_splits, shuffle=True, random_state=seed)
all_history = []
best_epochs = []

# Loop over each fold
for train_index, val_index in kf.split(data_unique):
    train_data, val_data = data_balanced[train_index], data_balanced[val_index]
    train_labels, val_labels = one_hot_labels[train_index], one_hot_labels[val_index]

    # Create a new instance of the model (this is important to reset weights)
    model = tf.keras.Model(inputs=inputs, outputs=output_layer, name='model') #note this has to be within the for loop since it re initialized the weights
    learning_rate = 5e-4  # This sets the learning rate to 0.00001
    model.compile(
        loss=tf.keras.losses.BinaryCrossentropy(),
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
    ) # dflt learning rate 1e-3


    # Train the model
    history = model.fit(
        x=train_data,
        y=train_labels,
        epochs=200,
        validation_data=(val_data, val_labels),
        #class_weight=class_weight_dict, #to be removed in case of upsampling/downsampling
        callbacks=callbacks,
    ).history

    all_history.append(history)

    # Store the best epoch for the current fold
    # if early stopping didn't occur, use the last epoch as the best epoch
    patience = 10
    best_epoch = early_stopping.stopped_epoch - (patience - 1) if early_stopping.stopped_epoch > 0 else 199
    best_epochs.append(best_epoch)
    average_best_epoch = sum(best_epochs)/len(best_epochs)
    print(f"best epoch: {best_epochs[-1]}")
    foldCount += 1
# Out:
# Epoch 1/200
# 114/114 [==============================] - 27s 113ms/step - loss: 0.4722 - accuracy: 0.7794 - precision_3: 0.7259 - recall_3: 0.6363 - val_loss: 0.3920 - val_accuracy: 0.8285 - val_precision_3: 0.9016 - val_recall_3: 0.6161 - lr: 5.0000e-04
# Epoch 2/200
# 114/114 [==============================] - 10s 88ms/step - loss: 0.4572 - accuracy: 0.7860 - precision_3: 0.7417 - recall_3: 0.6355 - val_loss: 0.3929 - val_accuracy: 0.8211 - val_precision_3: 0.8987 - val_recall_3: 0.5965 - lr: 5.0000e-04
# Epoch 3/200
# 114/114 [==============================] - 10s 91ms/step - loss: 0.4606 - accuracy: 0.7827 - precision_3: 0.7319 - recall_3: 0.6393 - val_loss: 0.3732 - val_accuracy: 0.8508 - val_precision_3: 0.8553 - val_recall_3: 0.7310 - lr: 5.0000e-04
# Epoch 4/200
# 114/114 [==============================] - 10s 92ms/step - loss: 0.4482 - accuracy: 0.7885 - precision_3: 0.7407 - recall_3: 0.6476 - val_loss: 0.3730 - val_accuracy: 0.8409 - val_precision_3: 0.7978 - val_recall_3: 0.7787 - lr: 5.0000e-04
# Epoch 5/200
# 114/114 [==============================] - 10s 85ms/step - loss: 0.4456 - accuracy: 0.7951 - precision_3: 0.7506 - recall_3: 0.6574 - val_loss: 0.3863 - val_accuracy: 0.8302 - val_precision_3: 0.8783 - val_recall_3: 0.6421 - lr: 5.0000e-04
# Epoch 6/200
# 114/114 [==============================] - 10s 88ms/step - loss: 0.4451 - accuracy: 0.7976 - precision_3: 0.7574 - recall_3: 0.6559 - val_loss: 0.3864 - val_accuracy: 0.8335 - val_precision_3: 0.8381 - val_recall_3: 0.6963 - lr: 5.0000e-04
# Epoch 7/200
# 114/114 [==============================] - 10s 90ms/step - loss: 0.4331 - accuracy: 0.8009 - precision_3: 0.7644 - recall_3: 0.6574 - val_loss: 0.3670 - val_accuracy: 0.8409 - val_precision_3: 0.7803 - val_recall_3: 0.8091 - lr: 5.0000e-04
# Epoch 8/200
# 114/114 [==============================] - 10s 85ms/step - loss: 0.4380 - accuracy: 0.8050 - precision_3: 0.7634 - recall_3: 0.6755 - val_loss: 0.4238 - val_accuracy: 0.8071 - val_precision_3: 0.8955 - val_recall_3: 0.5575 - lr: 5.0000e-04
# Epoch 9/200
# 114/114 [==============================] - 10s 90ms/step - loss: 0.4448 - accuracy: 0.7946 - precision_3: 0.7533 - recall_3: 0.6506 - val_loss: 0.3571 - val_accuracy: 0.8475 - val_precision_3: 0.8433 - val_recall_3: 0.7354 - lr: 5.0000e-04
# Epoch 10/200
# 114/114 [==============================] - 10s 88ms/step - loss: 0.4370 - accuracy: 0.7893 - precision_3: 0.7373 - recall_3: 0.6574 - val_loss: 0.3781 - val_accuracy: 0.8368 - val_precision_3: 0.8564 - val_recall_3: 0.6855 - lr: 5.0000e-04
# Epoch 11/200
# 114/114 [==============================] - 10s 90ms/step - loss: 0.4326 - accuracy: 0.7973 - precision_3: 0.7481 - recall_3: 0.6709 - val_loss: 0.3865 - val_accuracy: 0.8293 - val_precision_3: 0.8567 - val_recall_3: 0.6616 - lr: 5.0000e-04
# Epoch 12/200
# 114/114 [==============================] - 10s 92ms/step - loss: 0.4289 - accuracy: 0.8064 - precision_3: 0.7649 - recall_3: 0.6785 - val_loss: 0.3868 - val_accuracy: 0.8244 - val_precision_3: 0.8735 - val_recall_3: 0.6291 - lr: 5.0000e-04
# Epoch 13/200
# 114/114 [==============================] - 11s 97ms/step - loss: 0.4240 - accuracy: 0.8020 - precision_3: 0.7589 - recall_3: 0.6709 - val_loss: 0.3880 - val_accuracy: 0.8285 - val_precision_3: 0.8991 - val_recall_3: 0.6182 - lr: 5.0000e-04
# Epoch 14/200
# 114/114 [==============================] - 11s 97ms/step - loss: 0.4314 - accuracy: 0.8058 - precision_3: 0.7596 - recall_3: 0.6852 - val_loss: 0.3832 - val_accuracy: 0.8326 - val_precision_3: 0.9057 - val_recall_3: 0.6247 - lr: 5.0000e-04
# Epoch 15/200
# 114/114 [==============================] - ETA: 0s - loss: 0.4352 - accuracy: 0.7910 - precision_3: 0.7411 - recall_3: 0.6574
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 114/114 [==============================] - 11s 94ms/step - loss: 0.4352 - accuracy: 0.7910 - precision_3: 0.7411 - recall_3: 0.6574 - val_loss: 0.3730 - val_accuracy: 0.8392 - val_precision_3: 0.8866 - val_recall_3: 0.6616 - lr: 5.0000e-04
# Epoch 16/200
# 114/114 [==============================] - 10s 85ms/step - loss: 0.4202 - accuracy: 0.8089 - precision_3: 0.7698 - recall_3: 0.6800 - val_loss: 0.3695 - val_accuracy: 0.8376 - val_precision_3: 0.8860 - val_recall_3: 0.6573 - lr: 2.5000e-04
# Epoch 17/200
# 114/114 [==============================] - 11s 96ms/step - loss: 0.4084 - accuracy: 0.8174 - precision_3: 0.7833 - recall_3: 0.6913 - val_loss: 0.3545 - val_accuracy: 0.8491 - val_precision_3: 0.9017 - val_recall_3: 0.6768 - lr: 2.5000e-04
# Epoch 18/200
# 114/114 [==============================] - 10s 91ms/step - loss: 0.4040 - accuracy: 0.8163 - precision_3: 0.7905 - recall_3: 0.6762 - val_loss: 0.3454 - val_accuracy: 0.8508 - val_precision_3: 0.8763 - val_recall_3: 0.7072 - lr: 2.5000e-04
# Epoch 19/200
# 114/114 [==============================] - 11s 94ms/step - loss: 0.4218 - accuracy: 0.8056 - precision_3: 0.7638 - recall_3: 0.6770 - val_loss: 0.3765 - val_accuracy: 0.8343 - val_precision_3: 0.9194 - val_recall_3: 0.6182 - lr: 2.5000e-04
# Epoch 20/200
# 114/114 [==============================] - 12s 103ms/step - loss: 0.3961 - accuracy: 0.8248 - precision_3: 0.7956 - recall_3: 0.7003 - val_loss: 0.3383 - val_accuracy: 0.8500 - val_precision_3: 0.8496 - val_recall_3: 0.7354 - lr: 2.5000e-04
# Epoch 21/200
# 114/114 [==============================] - 10s 89ms/step - loss: 0.3965 - accuracy: 0.8168 - precision_3: 0.7754 - recall_3: 0.7018 - val_loss: 0.3642 - val_accuracy: 0.8343 - val_precision_3: 0.9088 - val_recall_3: 0.6269 - lr: 2.5000e-04
# Epoch 22/200
# 114/114 [==============================] - 10s 89ms/step - loss: 0.3940 - accuracy: 0.8212 - precision_3: 0.7927 - recall_3: 0.6913 - val_loss: 0.3436 - val_accuracy: 0.8508 - val_precision_3: 0.8825 - val_recall_3: 0.7007 - lr: 2.5000e-04
# Epoch 23/200
# 114/114 [==============================] - 11s 93ms/step - loss: 0.3879 - accuracy: 0.8278 - precision_3: 0.7920 - recall_3: 0.7169 - val_loss: 0.3440 - val_accuracy: 0.8541 - val_precision_3: 0.8944 - val_recall_3: 0.6985 - lr: 2.5000e-04
# Epoch 24/200
# 114/114 [==============================] - 11s 93ms/step - loss: 0.4146 - accuracy: 0.8069 - precision_3: 0.7662 - recall_3: 0.6785 - val_loss: 0.3445 - val_accuracy: 0.8516 - val_precision_3: 0.8828 - val_recall_3: 0.7028 - lr: 2.5000e-04
# Epoch 25/200
# 114/114 [==============================] - 11s 96ms/step - loss: 0.4015 - accuracy: 0.8094 - precision_3: 0.7644 - recall_3: 0.6913 - val_loss: 0.3610 - val_accuracy: 0.8392 - val_precision_3: 0.9236 - val_recall_3: 0.6291 - lr: 2.5000e-04
# Epoch 26/200
# 114/114 [==============================] - 12s 101ms/step - loss: 0.3892 - accuracy: 0.8199 - precision_3: 0.7770 - recall_3: 0.7108 - val_loss: 0.3374 - val_accuracy: 0.8533 - val_precision_3: 0.8986 - val_recall_3: 0.6920 - lr: 2.5000e-04
# Epoch 27/200
# 114/114 [==============================] - 10s 86ms/step - loss: 0.4027 - accuracy: 0.8218 - precision_3: 0.7852 - recall_3: 0.7048 - val_loss: 0.3627 - val_accuracy: 0.8442 - val_precision_3: 0.9146 - val_recall_3: 0.6508 - lr: 2.5000e-04
# Epoch 28/200
# 114/114 [==============================] - 11s 95ms/step - loss: 0.4011 - accuracy: 0.8075 - precision_3: 0.7630 - recall_3: 0.6860 - val_loss: 0.3555 - val_accuracy: 0.8401 - val_precision_3: 0.9108 - val_recall_3: 0.6421 - lr: 2.5000e-04
# Epoch 29/200
# 114/114 [==============================] - 10s 90ms/step - loss: 0.3928 - accuracy: 0.8204 - precision_3: 0.7872 - recall_3: 0.6965 - val_loss: 0.3382 - val_accuracy: 0.8549 - val_precision_3: 0.8663 - val_recall_3: 0.7310 - lr: 2.5000e-04
# Epoch 30/200
# 114/114 [==============================] - 11s 98ms/step - loss: 0.4035 - accuracy: 0.8201 - precision_3: 0.7837 - recall_3: 0.7011 - val_loss: 0.3267 - val_accuracy: 0.8640 - val_precision_3: 0.8410 - val_recall_3: 0.7918 - lr: 2.5000e-04
# Epoch 31/200
# 114/114 [==============================] - 11s 94ms/step - loss: 0.4097 - accuracy: 0.8207 - precision_3: 0.7899 - recall_3: 0.6935 - val_loss: 0.3422 - val_accuracy: 0.8566 - val_precision_3: 0.8526 - val_recall_3: 0.7527 - lr: 2.5000e-04
# Epoch 32/200
# 114/114 [==============================] - 10s 90ms/step - loss: 0.3950 - accuracy: 0.8171 - precision_3: 0.7793 - recall_3: 0.6965 - val_loss: 0.3387 - val_accuracy: 0.8491 - val_precision_3: 0.8757 - val_recall_3: 0.7028 - lr: 2.5000e-04
# Epoch 33/200
# 114/114 [==============================] - 10s 86ms/step - loss: 0.3949 - accuracy: 0.8254 - precision_3: 0.7895 - recall_3: 0.7116 - val_loss: 0.3553 - val_accuracy: 0.8450 - val_precision_3: 0.9050 - val_recall_3: 0.6616 - lr: 2.5000e-04
# Epoch 34/200
# 114/114 [==============================] - 10s 89ms/step - loss: 0.3966 - accuracy: 0.8254 - precision_3: 0.7959 - recall_3: 0.7018 - val_loss: 0.3611 - val_accuracy: 0.8335 - val_precision_3: 0.9164 - val_recall_3: 0.6182 - lr: 2.5000e-04
# Epoch 35/200
# 114/114 [==============================] - 10s 88ms/step - loss: 0.3875 - accuracy: 0.8251 - precision_3: 0.7893 - recall_3: 0.7108 - val_loss: 0.3365 - val_accuracy: 0.8467 - val_precision_3: 0.8747 - val_recall_3: 0.6963 - lr: 2.5000e-04
# Epoch 36/200
# 113/114 [============================>.] - ETA: 0s - loss: 0.4049 - accuracy: 0.8103 - precision_3: 0.7723 - recall_3: 0.6811
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 114/114 [==============================] - 10s 88ms/step - loss: 0.4052 - accuracy: 0.8102 - precision_3: 0.7726 - recall_3: 0.6807 - val_loss: 0.3330 - val_accuracy: 0.8574 - val_precision_3: 0.8600 - val_recall_3: 0.7462 - lr: 2.5000e-04
# Epoch 37/200
# 114/114 [==============================] - 10s 91ms/step - loss: 0.3855 - accuracy: 0.8325 - precision_3: 0.8003 - recall_3: 0.7214 - val_loss: 0.3355 - val_accuracy: 0.8590 - val_precision_3: 0.8836 - val_recall_3: 0.7245 - lr: 1.2500e-04
# Epoch 38/200
# 114/114 [==============================] - 10s 85ms/step - loss: 0.3880 - accuracy: 0.8218 - precision_3: 0.7872 - recall_3: 0.7018 - val_loss: 0.3576 - val_accuracy: 0.8475 - val_precision_3: 0.8812 - val_recall_3: 0.6920 - lr: 1.2500e-04
# Epoch 39/200
# 114/114 [==============================] - 10s 89ms/step - loss: 0.3756 - accuracy: 0.8377 - precision_3: 0.8106 - recall_3: 0.7252 - val_loss: 0.3509 - val_accuracy: 0.8467 - val_precision_3: 0.8873 - val_recall_3: 0.6833 - lr: 1.2500e-04
# Epoch 40/200
# 114/114 [==============================] - 10s 89ms/step - loss: 0.3767 - accuracy: 0.8391 - precision_3: 0.8135 - recall_3: 0.7259 - val_loss: 0.3438 - val_accuracy: 0.8500 - val_precision_3: 0.8886 - val_recall_3: 0.6920 - lr: 1.2500e-04
# best epoch: 30
# Epoch 1/200
# 114/114 [==============================] - 24s 138ms/step - loss: 0.4218 - accuracy: 0.7982 - precision_4: 0.7624 - recall_4: 0.6745 - val_loss: 0.3124 - val_accuracy: 0.8581 - val_precision_4: 0.9244 - val_recall_4: 0.6420 - lr: 5.0000e-04
# Epoch 2/200
# 114/114 [==============================] - 10s 86ms/step - loss: 0.3995 - accuracy: 0.8152 - precision_4: 0.7828 - recall_4: 0.7051 - val_loss: 0.3081 - val_accuracy: 0.8639 - val_precision_4: 0.7860 - val_recall_4: 0.8329 - lr: 5.0000e-04
# Epoch 3/200
# 114/114 [==============================] - 11s 96ms/step - loss: 0.4111 - accuracy: 0.8073 - precision_4: 0.7632 - recall_4: 0.7080 - val_loss: 0.3237 - val_accuracy: 0.8465 - val_precision_4: 0.8949 - val_recall_4: 0.6301 - lr: 5.0000e-04
# Epoch 4/200
# 114/114 [==============================] - 10s 89ms/step - loss: 0.4122 - accuracy: 0.8097 - precision_4: 0.7678 - recall_4: 0.7095 - val_loss: 0.3068 - val_accuracy: 0.8606 - val_precision_4: 0.8698 - val_recall_4: 0.7017 - lr: 5.0000e-04
# Epoch 5/200
# 114/114 [==============================] - 10s 89ms/step - loss: 0.4161 - accuracy: 0.8108 - precision_4: 0.7715 - recall_4: 0.7073 - val_loss: 0.3046 - val_accuracy: 0.8663 - val_precision_4: 0.8173 - val_recall_4: 0.7900 - lr: 5.0000e-04
# Epoch 6/200
# 114/114 [==============================] - 11s 93ms/step - loss: 0.4046 - accuracy: 0.8183 - precision_4: 0.7870 - recall_4: 0.7095 - val_loss: 0.3043 - val_accuracy: 0.8663 - val_precision_4: 0.7901 - val_recall_4: 0.8353 - lr: 5.0000e-04
# Epoch 7/200
# 114/114 [==============================] - 10s 90ms/step - loss: 0.4118 - accuracy: 0.8119 - precision_4: 0.7692 - recall_4: 0.7153 - val_loss: 0.3091 - val_accuracy: 0.8622 - val_precision_4: 0.8818 - val_recall_4: 0.6945 - lr: 5.0000e-04
# Epoch 18/200
# 114/114 [==============================] - 10s 89ms/step - loss: 0.3937 - accuracy: 0.8205 - precision_4: 0.7821 - recall_4: 0.7255 - val_loss: 0.2981 - val_accuracy: 0.8663 - val_precision_4: 0.8978 - val_recall_4: 0.6921 - lr: 2.5000e-04
# Epoch 19/200
# 114/114 [==============================] - 10s 91ms/step - loss: 0.3920 - accuracy: 0.8251 - precision_4: 0.7872 - recall_4: 0.7343 - val_loss: 0.2962 - val_accuracy: 0.8696 - val_precision_4: 0.8919 - val_recall_4: 0.7088 - lr: 2.5000e-04
# best epoch: 9
# Epoch 1/200
# 114/114 [==============================] - 21s 113ms/step - loss: 0.3899 - accuracy: 0.8260 - precision_5: 0.7810 - recall_5: 0.7351 - val_loss: 0.3205 - val_accuracy: 0.8548 - val_precision_5: 0.9039 - val_recall_5: 0.6764 - lr: 5.0000e-04
# Epoch 2/200
# 114/114 [==============================] - 10s 88ms/step - loss: 0.4059 - accuracy: 0.8163 - precision_5: 0.7812 - recall_5: 0.6987 - val_loss: 0.3377 - val_accuracy: 0.8465 - val_precision_5: 0.7648 - val_recall_5: 0.8404 - lr: 5.0000e-04
# Epoch 3/200
# 114/114 [==============================] - 11s 93ms/step - loss: 0.3927 - accuracy: 0.8295 - precision_5: 0.7938 - recall_5: 0.7277 - val_loss: 0.3296 - val_accuracy: 0.8622 - val_precision_5: 0.8639 - val_recall_5: 0.7416 - lr: 5.0000e-04
# Epoch 4/200
# 114/114 [==============================] - 10s 88ms/step - loss: 0.4018 - accuracy: 0.8161 - precision_5: 0.7698 - recall_5: 0.7165 - val_loss: 0.3196 - val_accuracy: 0.8597 - val_precision_5: 0.8686 - val_recall_5: 0.7281 - lr: 5.0000e-04
# Epoch 5/200
# 114/114 [==============================] - 10s 89ms/step - loss: 0.3766 - accuracy: 0.8372 - precision_5: 0.8018 - recall_5: 0.7433 - val_loss: 0.3211 - val_accuracy: 0.8614 - val_precision_5: 0.8858 - val_recall_5: 0.7146 - lr: 5.0000e-04
# Epoch 6/200
# 114/114 [==============================] - 11s 93ms/step - loss: 0.3890 - accuracy: 0.8317 - precision_5: 0.8000 - recall_5: 0.7262 - val_loss: 0.3694 - val_accuracy: 0.8177 - val_precision_5: 0.6958 - val_recall_5: 0.8944 - lr: 5.0000e-04
# Epoch 7/200
# 114/114 [==============================] - 10s 86ms/step - loss: 0.3936 - accuracy: 0.8196 - precision_5: 0.7770 - recall_5: 0.7180 - val_loss: 0.3246 - val_accuracy: 0.8630 - val_precision_5: 0.8623 - val_recall_5: 0.7461 - lr: 5.0000e-04
# Epoch 8/200
# 114/114 [==============================] - 10s 90ms/step - loss: 0.3858 - accuracy: 0.8265 - precision_5: 0.7939 - recall_5: 0.7165 - val_loss: 0.3327 - val_accuracy: 0.8531 - val_precision_5: 0.8414 - val_recall_5: 0.7393 - lr: 5.0000e-04
# Epoch 9/200
# 114/114 [==============================] - 10s 92ms/step - loss: 0.3860 - accuracy: 0.8205 - precision_5: 0.7793 - recall_5: 0.7173 - val_loss: 0.3493 - val_accuracy: 0.8375 - val_precision_5: 0.9276 - val_recall_5: 0.6045 - lr: 5.0000e-04
# Epoch 10/200
# 113/114 [============================>.] - ETA: 0s - loss: 0.3858 - accuracy: 0.8261 - precision_5: 0.7882 - recall_5: 0.7226
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 114/114 [==============================] - 10s 85ms/step - loss: 0.3855 - accuracy: 0.8262 - precision_5: 0.7890 - recall_5: 0.7232 - val_loss: 0.3287 - val_accuracy: 0.8581 - val_precision_5: 0.8370 - val_recall_5: 0.7618 - lr: 5.0000e-04
# Epoch 11/200
# 114/114 [==============================] - 10s 91ms/step - loss: 0.3843 - accuracy: 0.8312 - precision_5: 0.7929 - recall_5: 0.7351 - val_loss: 0.3237 - val_accuracy: 0.8498 - val_precision_5: 0.8768 - val_recall_5: 0.6876 - lr: 2.5000e-04
# Epoch 12/200
# 114/114 [==============================] - 10s 88ms/step - loss: 0.3816 - accuracy: 0.8257 - precision_5: 0.7915 - recall_5: 0.7173 - val_loss: 0.3556 - val_accuracy: 0.8391 - val_precision_5: 0.8906 - val_recall_5: 0.6404 - lr: 2.5000e-04
# Epoch 13/200
# 114/114 [==============================] - 10s 88ms/step - loss: 0.3635 - accuracy: 0.8414 - precision_5: 0.8100 - recall_5: 0.7455 - val_loss: 0.3356 - val_accuracy: 0.8465 - val_precision_5: 0.8936 - val_recall_5: 0.6607 - lr: 2.5000e-04
# Epoch 14/200
# 114/114 [==============================] - 11s 94ms/step - loss: 0.3844 - accuracy: 0.8257 - precision_5: 0.7881 - recall_5: 0.7225 - val_loss: 0.3274 - val_accuracy: 0.8515 - val_precision_5: 0.8478 - val_recall_5: 0.7258 - lr: 2.5000e-04
# best epoch: 4
# Epoch 1/200
# 114/114 [==============================] - 20s 104ms/step - loss: 0.4074 - accuracy: 0.8114 - precision_6: 0.7643 - recall_6: 0.6974 - val_loss: 0.3123 - val_accuracy: 0.8680 - val_precision_6: 0.9524 - val_recall_6: 0.6897 - lr: 5.0000e-04
# Epoch 2/200
# 114/114 [==============================] - 10s 92ms/step - loss: 0.4051 - accuracy: 0.8075 - precision_6: 0.7651 - recall_6: 0.6808 - val_loss: 0.2844 - val_accuracy: 0.8952 - val_precision_6: 0.8946 - val_recall_6: 0.8233 - lr: 5.0000e-04
# Epoch 3/200
# 114/114 [==============================] - 10s 89ms/step - loss: 0.3834 - accuracy: 0.8243 - precision_6: 0.7887 - recall_6: 0.7072 - val_loss: 0.3082 - val_accuracy: 0.8688 - val_precision_6: 0.9201 - val_recall_6: 0.7198 - lr: 5.0000e-04
# Epoch 4/200
# 114/114 [==============================] - 10s 88ms/step - loss: 0.4098 - accuracy: 0.8117 - precision_6: 0.7627 - recall_6: 0.7011 - val_loss: 0.3070 - val_accuracy: 0.8688 - val_precision_6: 0.9201 - val_recall_6: 0.7198 - lr: 5.0000e-04
# Epoch 5/200
# Epoch 25/200
# 114/114 [==============================] - 10s 91ms/step - loss: 0.3708 - accuracy: 0.8372 - precision_6: 0.8077 - recall_6: 0.7260 - val_loss: 0.2924 - val_accuracy: 0.8771 - val_precision_6: 0.9339 - val_recall_6: 0.7306 - lr: 6.2500e-05
# Epoch 26/200
# 114/114 [==============================] - 10s 85ms/step - loss: 0.3717 - accuracy: 0.8361 - precision_6: 0.8086 - recall_6: 0.7208 - val_loss: 0.2921 - val_accuracy: 0.8779 - val_precision_6: 0.9365 - val_recall_6: 0.7306 - lr: 6.2500e-05
# Epoch 27/200
# 114/114 [==============================] - 10s 91ms/step - loss: 0.3575 - accuracy: 0.8400 - precision_6: 0.8119 - recall_6: 0.7298 - val_loss: 0.2826 - val_accuracy: 0.8837 - val_precision_6: 0.9261 - val_recall_6: 0.7565 - lr: 6.2500e-05
# best epoch: 17

# %%
# Use the best average epoch from your cross-validation
average_best_epoch = sum(best_epochs)/len(best_epochs)
final_epochs = int(average_best_epoch)

# Create a new model instance (resetting weights)
model = tf.keras.Model(inputs=inputs, outputs=output_layer, name='final_model') #this has to be run to be able to run fine tunng afterwards

learning_rate = 2e-4  # This sets the learning rate to 0.00001
model.compile(
        loss=tf.keras.losses.BinaryCrossentropy(),
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
    )

# Train the model on the entire dataset
model.fit(
    x=data_balanced,  # Your entire dataset
    y=one_hot_labels,
    epochs=final_epochs,
    #class_weight=class_weight_dict,
    batch_size = 32, #64
    validation_data = (val_data, val_labels),
    callbacks = callbacks,
)


#model.save('WeightedKfoldModelSlowLR')
#del model

# %% [markdown]
# ### normal training without kfold cross-validation and on upsampled test set

# %%
# Train the model
history = model.fit(
    x = train_data,
    y= train_labels,
    epochs = 200,
    batch_size = 32, #64
    validation_data = (val_data, val_labels),
    callbacks = callbacks,
).history
# Out:
# Epoch 1/200
# 129/129 [==============================] - 20s 100ms/step - loss: 0.5562 - accuracy: 0.7171 - val_loss: 0.4290 - val_accuracy: 0.8104 - lr: 5.0000e-04
# Epoch 2/200
# 129/129 [==============================] - 11s 89ms/step - loss: 0.5131 - accuracy: 0.7496 - val_loss: 0.4269 - val_accuracy: 0.8118 - lr: 5.0000e-04
# Epoch 3/200
# 129/129 [==============================] - 10s 80ms/step - loss: 0.5114 - accuracy: 0.7503 - val_loss: 0.4268 - val_accuracy: 0.8077 - lr: 5.0000e-04
# Epoch 4/200
# 129/129 [==============================] - 11s 87ms/step - loss: 0.4728 - accuracy: 0.7765 - val_loss: 0.4014 - val_accuracy: 0.8187 - lr: 5.0000e-04
# Epoch 5/200
# 129/129 [==============================] - 10s 79ms/step - loss: 0.4761 - accuracy: 0.7709 - val_loss: 0.4053 - val_accuracy: 0.8269 - lr: 5.0000e-04
# Epoch 6/200
# 129/129 [==============================] - 10s 78ms/step - loss: 0.4741 - accuracy: 0.7743 - val_loss: 0.4309 - val_accuracy: 0.8091 - lr: 5.0000e-04
# Epoch 7/200
# 129/129 [==============================] - 11s 84ms/step - loss: 0.4694 - accuracy: 0.7789 - val_loss: 0.4117 - val_accuracy: 0.8173 - lr: 5.0000e-04
# 129/129 [==============================] - 11s 88ms/step - loss: 0.4196 - accuracy: 0.8124 - val_loss: 0.3625 - val_accuracy: 0.8475 - lr: 5.0000e-04
# Epoch 25/200
# 129/129 [==============================] - 11s 87ms/step - loss: 0.4252 - accuracy: 0.8051 - val_loss: 0.3497 - val_accuracy: 0.8475 - lr: 5.0000e-04
# Epoch 26/200
# 129/129 [==============================] - 11s 84ms/step - loss: 0.4177 - accuracy: 0.8047 - val_loss: 0.3875 - val_accuracy: 0.8420 - lr: 5.0000e-04
# Epoch 27/200
# 129/129 [==============================] - 11s 87ms/step - loss: 0.4088 - accuracy: 0.8175 - val_loss: 0.3747 - val_accuracy: 0.8365 - lr: 5.0000e-04
# Epoch 28/200
# 129/129 [==============================] - 11s 88ms/step - loss: 0.4245 - accuracy: 0.8034 - val_loss: 0.3869 - val_accuracy: 0.8420 - lr: 5.0000e-04
# Epoch 29/200
# 129/129 [==============================] - ETA: 0s - loss: 0.4043 - accuracy: 0.8088
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 129/129 [==============================] - 11s 86ms/step - loss: 0.4043 - accuracy: 0.8088 - val_loss: 0.4163 - val_accuracy: 0.8159 - lr: 5.0000e-04
# Epoch 30/200
# 129/129 [==============================] - 10s 75ms/step - loss: 0.4097 - accuracy: 0.8117 - val_loss: 0.3813 - val_accuracy: 0.8420 - lr: 2.5000e-04
# Epoch 31/200
# 129/129 [==============================] - 11s 89ms/step - loss: 0.4101 - accuracy: 0.8151 - val_loss: 0.3662 - val_accuracy: 0.8434 - lr: 2.5000e-04
# Epoch 32/200
# 129/129 [==============================] - 11s 87ms/step - loss: 0.4157 - accuracy: 0.8090 - val_loss: 0.3519 - val_accuracy: 0.8503 - lr: 2.5000e-04
# Epoch 33/200
# 129/129 [==============================] - 10s 75ms/step - loss: 0.3954 - accuracy: 0.8238 - val_loss: 0.3675 - val_accuracy: 0.8448 - lr: 2.5000e-04
# Epoch 34/200
# 129/129 [==============================] - 10s 79ms/step - loss: 0.4057 - accuracy: 0.8085 - val_loss: 0.3567 - val_accuracy: 0.8530 - lr: 2.5000e-04
# Epoch 35/200
# 129/129 [==============================] - ETA: 0s - loss: 0.3940 - accuracy: 0.8243
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 129/129 [==============================] - 10s 79ms/step - loss: 0.3940 - accuracy: 0.8243 - val_loss: 0.3599 - val_accuracy: 0.8434 - lr: 2.5000e-04

# %%
# Plot the training
plt.figure(figsize=(15,5))

plt.plot(history['loss'],label = 'Training Loss', alpha=.3, color='#4D61E2', linestyle='--')
plt.plot(history['val_loss'], label='Validation Loss', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Binary Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))

plt.plot(history['accuracy'],label = 'Training Accuracy' , alpha=.3, color='#4D61E2', linestyle='--')
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# %ls
# Out:
#  baseLineModel/                               EfficientNetXXX1SmallBatchFT/
#  BaseLine_simpleCNN.ipynb                     EfficientNetXXX1SmallBatchFT2/
# 'Copia di Copia di ResNet152V2_96.ipynb'      EfficientNetXXX1SmallBatchTL/
#  duplicates/                                  EffiecientNet_weighted.ipynb
#  efficientNet087Base.ipynb                    ensemble.ipynb
#  EfficientNet_087.ipynb                       firstModelLuca.ipynb
#  EfficientNet_088.ipynb                       last_hope/
#  EfficientNet_088Mixup.ipynb                  last_hope2/
#  EfficientNet_088_reducedAugmentation.ipynb   model.png
#  EfficientNet_B3.ipynb                        progressiveFTModel/
#  efficientNetTTA.0874/                        ResNet152V2_96.ipynb
#  EfficientNet_withProgressiveFT.ipynb         Resnet152v2fine_tuned/
#  EFFICIENTNETXX1TTA/                          ResnetV1TL/
#  EFFICIENTNETXX1TTAft/                       'Transfer Learning and Fine Tuning.ipynb'
#  EfficientNetXXX1/                            WeightedKfoldModel/
#  EfficientNetXXX116BatchTL/                   WeightedKfoldModelSlowLR/
#  EfficientNetXXX164BatchTLmMIXUP/             XceptionNetFinal.ipynb
#  EfficientNetXXX164BatchTLmMIXUPft/           Xception_zano.ipynb
#  EfficientNetXXX164BatchTLNoTranslation/      ZERO88160EPOCHS/
#  EfficientNetXXX164BatchTLNoTranslationFT/    ZERO8876EPOCHS/
#  EfficientNetXXX1_fine_tuning1/               ZERO8894accuracy48EPOCHS/

# %%
model.save('efficientNetNoUpsamplingFinal')
del model

# %%
max_accuracy = max(history['accuracy'])
max_val_accuracy = max(history['val_accuracy'])

print(f"Maximum training accuracy: {max_accuracy}")
print(f"Maximum validation accuracy: {max_val_accuracy}")

# %% [markdown]
# ## FINE TUNING

# %%
# Re-load the model after transfer learning
#model = tfk.models.load_model('efficientNetXXX1_fine_tuning1')
model = tfk.models.load_model('efficientNetNoUpsamplingFinal')

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  preprocessing (Sequential)  (None, 96, 96, 3)         0
#
#  resizing_1 (Resizing)       (None, 224, 224, 3)       0
#
#  efficientnetb0 (Functional  (None, 7, 7, 1280)        4049571
#  )
#
#  global_average_pooling2d_1  (None, 1280)              0
#   (GlobalAveragePooling2D)
#
#  dropout_1 (Dropout)         (None, 1280)              0
#
#  dense_1 (Dense)             (None, 1024)              1311744
#
#  Output (Dense)              (None, 1)                 1025
#
# =================================================================
# Total params: 5362340 (20.46 MB)
# Trainable params: 1312769 (5.01 MB)
# Non-trainable params: 4049571 (15.45 MB)
# _________________________________________________________________

# %%
# Set all layers to Trainable
model.get_layer('efficientnetb0').trainable = True

# %%
#FINETUNING BLOCKs 6, 7
for i, layer in enumerate(model.get_layer('efficientnetb0').layers[:163]):
  layer.trainable=False
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  preprocessing (Sequential)  (None, 96, 96, 3)         0
#
#  resizing_1 (Resizing)       (None, 224, 224, 3)       0
#
#  efficientnetb0 (Functional  (None, 7, 7, 1280)        4049571
#  )
#
#  global_average_pooling2d_1  (None, 1280)              0
#   (GlobalAveragePooling2D)
#
#  dropout_1 (Dropout)         (None, 1280)              0
#
#  dense_1 (Dense)             (None, 1024)              1311744
#
#  Output (Dense)              (None, 1)                 1025
#
# =================================================================
# Total params: 5362340 (20.46 MB)
# Trainable params: 4468509 (17.05 MB)
# Non-trainable params: 893831 (3.41 MB)
# _________________________________________________________________

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=11, restore_best_weights=True)

rlrop = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience= 6, factor= 0.5, min_lr= 2e-6, verbose=1)

callbacks2 = []

callbacks2.append(rlrop)
callbacks2.append(early_stopping)

# %%
# Ricompila il modello con un learning rate più basso per il fine-tuning
model.compile(
    loss=tfk.losses.BinaryCrossentropy(),
    optimizer=tfk.optimizers.Adam(learning_rate=2e-5),  # un learning rate più basso per il fine-tuning
    metrics=['accuracy']
)

# %%
# Continua l'allenamento con fine-tuning
history_fine_tune = model.fit(
    x = train_data,
    y = train_labels,
    epochs = 150,
    batch_size = 32,
    validation_data = (val_data, val_labels),
    callbacks = callbacks2,
).history
# Out:
# Epoch 1/150
# 129/129 [==============================] - 36s 132ms/step - loss: 0.4017 - accuracy: 0.8187 - val_loss: 0.3500 - val_accuracy: 0.8544 - lr: 2.0000e-05
# Epoch 2/150
# 129/129 [==============================] - 15s 118ms/step - loss: 0.3787 - accuracy: 0.8335 - val_loss: 0.3695 - val_accuracy: 0.8503 - lr: 2.0000e-05
# Epoch 3/150
# 129/129 [==============================] - 14s 110ms/step - loss: 0.3615 - accuracy: 0.8347 - val_loss: 0.3185 - val_accuracy: 0.8571 - lr: 2.0000e-05
# Epoch 4/150
# 129/129 [==============================] - 15s 118ms/step - loss: 0.3585 - accuracy: 0.8389 - val_loss: 0.3130 - val_accuracy: 0.8695 - lr: 2.0000e-05
# Epoch 5/150
# 129/129 [==============================] - 15s 117ms/step - loss: 0.3421 - accuracy: 0.8476 - val_loss: 0.3088 - val_accuracy: 0.8654 - lr: 2.0000e-05
# Epoch 6/150
# 129/129 [==============================] - 15s 117ms/step - loss: 0.3348 - accuracy: 0.8559 - val_loss: 0.3029 - val_accuracy: 0.8681 - lr: 2.0000e-05
# Epoch 7/150
# 129/129 [==============================] - 15s 117ms/step - loss: 0.3185 - accuracy: 0.8614 - val_loss: 0.3151 - val_accuracy: 0.8736 - lr: 2.0000e-05
# Epoch 8/150
# 129/129 [==============================] - 15s 117ms/step - loss: 0.3148 - accuracy: 0.8614 - val_loss: 0.3061 - val_accuracy: 0.8709 - lr: 2.0000e-05
# Epoch 9/150
# 129/129 [==============================] - 14s 108ms/step - loss: 0.3129 - accuracy: 0.8634 - val_loss: 0.2920 - val_accuracy: 0.8723 - lr: 2.0000e-05
# Epoch 10/150
# 129/129 [==============================] - 15s 116ms/step - loss: 0.2861 - accuracy: 0.8782 - val_loss: 0.2969 - val_accuracy: 0.8709 - lr: 2.0000e-05
# Epoch 11/150
# 129/129 [==============================] - 15s 116ms/step - loss: 0.2895 - accuracy: 0.8794 - val_loss: 0.3291 - val_accuracy: 0.8599 - lr: 2.0000e-05
# Epoch 12/150
# 129/129 [==============================] - 15s 116ms/step - loss: 0.2761 - accuracy: 0.8845 - val_loss: 0.2796 - val_accuracy: 0.8764 - lr: 2.0000e-05
# Epoch 13/150
# 129/129 [==============================] - 14s 107ms/step - loss: 0.2759 - accuracy: 0.8833 - val_loss: 0.2833 - val_accuracy: 0.8860 - lr: 2.0000e-05
# Epoch 14/150
# 129/129 [==============================] - 15s 116ms/step - loss: 0.2697 - accuracy: 0.8826 - val_loss: 0.3091 - val_accuracy: 0.8709 - lr: 2.0000e-05
# Epoch 15/150
ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 129/129 [==============================] - 14s 108ms/step - loss: 0.1905 - accuracy: 0.9233 - val_loss: 0.2709 - val_accuracy: 0.8970 - lr: 5.0000e-06
# Epoch 47/150
# 129/129 [==============================] - 15s 116ms/step - loss: 0.1713 - accuracy: 0.9325 - val_loss: 0.2817 - val_accuracy: 0.8984 - lr: 2.5000e-06
# Epoch 48/150
# 129/129 [==============================] - 15s 117ms/step - loss: 0.1973 - accuracy: 0.9185 - val_loss: 0.2810 - val_accuracy: 0.8984 - lr: 2.5000e-06
# Epoch 49/150
# 129/129 [==============================] - 15s 117ms/step - loss: 0.1842 - accuracy: 0.9253 - val_loss: 0.2774 - val_accuracy: 0.8956 - lr: 2.5000e-06
# Epoch 50/150
# 129/129 [==============================] - 14s 107ms/step - loss: 0.1810 - accuracy: 0.9226 - val_loss: 0.2853 - val_accuracy: 0.8929 - lr: 2.5000e-06
# Epoch 51/150
# 129/129 [==============================] - 15s 118ms/step - loss: 0.1758 - accuracy: 0.9272 - val_loss: 0.2750 - val_accuracy: 0.8997 - lr: 2.5000e-06

# %%
max_accuracy = max(history_fine_tune['accuracy'])
max_val_accuracy = max(history_fine_tune['val_accuracy'])

print(f"Maximum training accuracy: {max_accuracy}")
print(f"Maximum validation accuracy: {max_val_accuracy}")
# Out:
# Maximum training accuracy: 0.9325406551361084
# Maximum validation accuracy: 0.901098906993866

# %%
# Plot the training
plt.figure(figsize=(15,5))

plt.plot(history['loss'],label = 'Training Loss', alpha=.3, color='#4D61E2', linestyle='--')
plt.plot(history['val_loss'], label='Validation Loss', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Binary Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))

plt.plot(history['accuracy'],label = 'Training Accuracy' , alpha=.3, color='#4D61E2', linestyle='--')
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
model.save('efficientNetNoUpsamplingFinal_fineTuned')

# %%
# %ls
# Out:
#  baseLineModel/                               EfficientNetXXX1_fine_tuning1/
#  BaseLine_simpleCNN.ipynb                     EfficientNetXXX1SmallBatchFT/
# 'Copia di Copia di ResNet152V2_96.ipynb'      EfficientNetXXX1SmallBatchFT2/
#  duplicates/                                  EfficientNetXXX1SmallBatchTL/
#  efficientNet087Base.ipynb                    EffiecientNet_weighted.ipynb
#  EfficientNet_087.ipynb                       ensemble.ipynb
#  EfficientNet_088.ipynb                       firstModelLuca.ipynb
#  EfficientNet_088Mixup.ipynb                  last_hope/
#  EfficientNet_088_reducedAugmentation.ipynb   last_hope2/
#  EfficientNet_B3.ipynb                        model.png
#  efficientNetNoUpsamplingFinal/               progressiveFTModel/
#  efficientNetNoUpsamplingFinal_fineTuned/     ResNet152V2_96.ipynb
#  efficientNetTTA.0874/                        Resnet152v2fine_tuned/
#  EfficientNet_withProgressiveFT.ipynb         ResnetV1TL/
#  EFFICIENTNETXX1TTA/                         'Transfer Learning and Fine Tuning.ipynb'
#  EFFICIENTNETXX1TTAft/                        WeightedKfoldModel/
#  EfficientNetXXX1/                            WeightedKfoldModelSlowLR/
#  EfficientNetXXX116BatchTL/                   XceptionNetFinal.ipynb
#  EfficientNetXXX164BatchTLmMIXUP/             Xception_zano.ipynb
#  EfficientNetXXX164BatchTLmMIXUPft/           ZERO88160EPOCHS/
#  EfficientNetXXX164BatchTLNoTranslation/      ZERO8876EPOCHS/
#  EfficientNetXXX164BatchTLNoTranslationFT/    ZERO8894accuracy48EPOCHS/

# %% [markdown]
# # TEST TIME AUGMENTATION

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

#define transformation to be applied during TTA
test_datagen = ImageDataGenerator(
    rotation_range=20,      # Rotate the image slightly (e.g., 20 degrees)
    width_shift_range=0.1,  # Shift the image horizontally
    height_shift_range=0.1, # Shift the image vertically
    horizontal_flip=True,   # Flip the image horizontally
    vertical_flip=True,     # Flip the image vertically
    #brightness_range=[0.8, 1.2]  # Adjust brightness (assuming this is the correct usage)
)

# %%
model2 = tfk.models.load_model('EfficientNetXXX1_fine_tuning1')

# %%
model = tfk.models.load_model('model2')

# %%
#this takes the highest probability prediction
def predict_with_tta_hprob(model, datagen, images, labels, num_augmentations=7):
    # Initialize an array to store the highest probability for each image
    highest_prob_predictions = np.zeros(len(images))

    for _ in range(num_augmentations):
        aug_iter = datagen.flow(images, labels, batch_size=len(images), shuffle=False)
        aug_images, _ = next(aug_iter)
        current_predictions = model.predict(aug_images).squeeze()

        # Update highest probability predictions
        highest_prob_predictions = np.maximum(highest_prob_predictions, current_predictions)

    return highest_prob_predictions

# %%
#this takes the avg of the predictions
def predict_with_tta_avg(model, datagen, images, labels, num_augmentations=7):
    predictions = np.zeros(len(images))  # Assuming binary classification

    for _ in range(num_augmentations):
        aug_iter = datagen.flow(images, labels, batch_size=len(images), shuffle=False)
        aug_images, _ = next(aug_iter)
        predictions += model.predict(aug_images).squeeze()
    predictions /= num_augmentations
    return predictions

# %%
from sklearn.metrics import accuracy_score

#make predictions with the two different variants to check which is better
tta_predictions1 = predict_with_tta_avg(model, test_datagen, val_data, val_labels)
tta_predictions2 = predict_with_tta_hprob(model, test_datagen, val_data, val_labels)

# Convert probabilities to class labels
tta_predictions_avg = (tta_predictions1 > 0.5).astype(int)
tta_predictions_hp = (tta_predictions2 > 0.5).astype(int)

# Evaluate performance
tta_accuracy_1 = accuracy_score(val_labels, tta_predictions_avg)
print(f"model1 tta accuract avg {tta_accuracy_1}")
tta_accuracy_2 = accuracy_score(val_labels, tta_predictions_hp)
print(f"model1 tta accuract hp {tta_accuracy_2}")
# Out:
# 29/29 [==============================] - 2s 58ms/step
# 29/29 [==============================] - 2s 61ms/step
# 29/29 [==============================] - 2s 58ms/step
# 29/29 [==============================] - 2s 59ms/step
# 29/29 [==============================] - 2s 61ms/step
# 29/29 [==============================] - 2s 59ms/step
# 29/29 [==============================] - 2s 59ms/step
# 29/29 [==============================] - 2s 63ms/step
# 29/29 [==============================] - 2s 58ms/step
# 29/29 [==============================] - 2s 59ms/step
# 29/29 [==============================] - 2s 63ms/step
# 29/29 [==============================] - 2s 59ms/step
# model1 tta accuract avg 0.9422657952069716
# model1 tta accuract hp 0.9455337690631809

# %%
print("Accuracy with TTA:", tta_accuracy)
BEST_TTA_ACCURACY= max(BEST_TTA_ACCURACY, tta_accuracy)
BEST_TTA_ACCURACY
# Out:
# Accuracy with TTA: 0.9628712871287128
# 0.9628712871287128

# %%
model.save('last_hope')
del model
